// %%
System.out.println("hola")
// Out:
// hola

// %%
a
// Out:
// |   a
// cannot find symbol
//   symbol:   variable a

// %%
float a

// %%
a = 10

// %%
a
// Out:
// 10.0

// %%
a*2
// Out:
// 20.0

// %%
class A{
    
}

// %%
for(int i=0; i<10; i++){
    System.out.println("hola:" + i);
}
// Out:
// hola:0
// hola:1
// hola:2
// hola:3
// hola:4
// hola:5
// hola:6
// hola:7
// hola:8
// hola:9

// %% [markdown]
// En la celda anterior se asdlkfjakjagfdj consdfag
